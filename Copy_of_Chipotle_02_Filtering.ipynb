# %% [markdown]
# <a href="https://colab.research.google.com/github/blaxman37/Laxman_github/blob/main/Copy_of_Chipotle_02_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')

# %%
chipo.head(50)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
new_type = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(new_type)

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
chipo[chipo['item_price']>10]['item_name'].nunique()
# Out:
# 31

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
#hint: use sort_values()

chipo.sort_values(['item_name'],ascending = True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.groupby(['item_name']).max().sort_values('item_price',ascending = False).head(1)
# Out:
#                               order_id  quantity choice_description  \
# item_name
# Chips and Fresh Tomato Salsa      1790        15                NaN
#
#                               item_price
# item_name
# Chips and Fresh Tomato Salsa       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl'].sum().loc['quantity']
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo_times = chipo[(chipo['quantity'] > 1) & (chipo['item_name'] == 'Canned Soda')]
chipo_times.quantity
# Out:
# 18      2
# 51      2
# 162     2
# 171     2
# 350     2
# 352     2
# 698     2
# 700     2
# 909     2
# 1091    2
# 1092    2
# 1944    2
# 2135    2
# 2235    4
# 2905    2
# 2906    2
# 3152    2
# 3364    2
# 3592    2
# 3866    2
# Name: quantity, dtype: int64
